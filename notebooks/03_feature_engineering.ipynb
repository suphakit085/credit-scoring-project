# %% [markdown]
# # 03. Feature Engineering
#
# ## Objectives
# - Create new features (e.g., Debt-to-Income (DTI), Payment Ratios)
# - Encode categorical variables (One-Hot, Label Encoding)
# - Feature Scaling
# - Feature Selection

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
